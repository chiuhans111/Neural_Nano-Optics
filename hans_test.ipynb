# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.load("./experimental/data/captures/138301.npy")
print(img.shape)
plt.imshow(img[0])
# Out:
# (1, 1080, 1080, 3)

# %%
psf = np.load("./experimental/data/psf/psf.npy")
print(psf.shape)
v = psf[0,300:400,300:400]**(2/2.2)
plt.imshow(v/(np.max(v)))
# Out:
# (1, 720, 720, 3)
